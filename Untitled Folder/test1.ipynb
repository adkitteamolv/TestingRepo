# %%
pip install langchain_community openai sentence_transformers
# Out:
# ...
#      |████████████████████████████████| 2.1MB 9.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 327kB 52.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 225kB 48.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 983kB 54.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 317kB 49.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1MB 42.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2MB 47.2MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 14.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 133kB 51.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 747kB 51.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 18.3MB 45.6MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 409kB 54.3MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 92kB 14.7MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 81kB 9.4MB/s  eta 0:00:01
# ...

# %%
import openai, os
from langchain_community.llms import AzureOpenAI
from langchain_community.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from langchain_community.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import SimpleSequentialChain
from langchain_community.document_loaders import TextLoader
#from langchain_chroma import Chroma
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
#from sentence_transformers import SentenceTransformer


embeddings = SentenceTransformerEmbeddings(model_name ="all-MiniLM-L6-v2") ##("all-MiniLM-L6-v2") 

print(embeddings)

openai.api_type = "azure"
openai.api_key = "840a080abe584b299d700c777616e216"
openai.api_base = "https://refract-openai.openai.azure.com/"
openai.api_version = "2023-03-15-preview"
dep_name="refract-gpt-35-turbo" # 'Refract-ada001'
model_name="refract-gpt-35-turbo" # 'Refract-ada001'
os.environ["OPENAI_API_TYPE"] = "azure"
os.environ["OPENAI_API_VERSION"] = "2023-03-15-preview"
os.environ["AZURE_ENDPOINT"] = "https://refract-openai.openai.azure.com/"
os.environ["DEPLOYMENT_NAME"] = dep_name
os.environ["OPENAI_API_KEY"] = "840a080abe584b299d700c777616e216"

os.environ["NOMIC_API_KEY"] = "nk-rZgcH0FJKDG0w1E3DpnyScnPknDBAqXk-CKypuyRpOo"




"""llm= AzureOpenAI(deployment_name=dep_name,
                 model_name=model_name,
 ''                base_url=openai.api_base,
                 temperature=0,
                 max_tokens=500)"""



##log_text="logId : 84317 , log : 2024-05-28T09:37:32.266Z  INFO 58 --- [       Thread-2] c.l.m.w.e.nodes.InputParamExtractor      : Extracted input parameters for reference id 'd4af9caf-f3e6-4c8a-98ab-e8515576bd1d' are: [{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ TIMESTAMP\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ lastSuccessfulRunDate\ ,\ parameterValue\ :\ 2024-05-28 05:35:35\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ TIMESTAMP\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ lastRunDate\ ,\ parameterValue\ :\ 2024-05-28 09:35:35\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ STRING\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ instanceId\ ,\ parameterValue\ :\ 297129\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ TIMESTAMP\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ currentTime\ ,\ parameterValue\ :\ 2024-05-28 09:37:32\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ STRING\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ objectName\ ,\ parameterValue\ :\ MASTER_DATA_WF_1\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ STRING\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ userId\ ,\ parameterValue\ :\ fdcuser@fosfor.com\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false}]. },{ logId : 86816 , log : 2024-05-28T09:37:32.266Z  INFO 58 --- [       Thread-2] c.l.m.w.e.nodes.InputParamExtractor      : Input params fetched are [{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ TIMESTAMP\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ lastSuccessfulRunDate\ ,\ parameterValue\ :\ 2024-05-28 05:35:35\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ TIMESTAMP\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ lastRunDate\ ,\ parameterValue\ :\ 2024-05-28 09:35:35\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ STRING\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ instanceId\ ,\ parameterValue\ :\ 297129\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ TIMESTAMP\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ currentTime\ ,\ parameterValue\ :\ 2024-05-28 09:37:32\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ STRING\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ objectName\ ,\ parameterValue\ :\ MASTER_DATA_WF_1\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false},{\ id\ :null,\ createdBy\ :\ SYSTEM\ ,\ createdDate\ :null,\ updatedBy\ :\ SYSTEM\ ,\ updatedDate\ :null,\ referenceId\ :\ d4af9caf-f3e6-4c8a-98ab-e8515576bd1d\ ,\ inputParameterType\ :\ SYSTEM\ ,\ inputParameterDataType\ :\ STRING\ ,\ inputReferenceType\ :\ WORKFLOW\ ,\ inputParameterName\ :\ userId\ ,\ parameterValue\ :\ fdcuser@fosfor.com\ ,\ version\ :null,\ projectId\ :null,\ fileName\ :null,\ secured\ :false}] },{ logId : 89251 , log : 2024-05-28T09:37:32.267Z  INFO 58 --- [       Thread-2] c.l.m.w.e.nodes.InputParamExtractor      : Extracted and resolved Workflow input parameters are {currentTime=2024-05-28 09:35:35, instanceId=00000, objectName=MASTER_DATA_WF_1, lastRunDate=, lastSuccessfulRunDate=, userId=fdcuser@fosfor.com}. },{ logId : 89590 , log : 2024-05-28T09:37:32.268Z  INFO 58 --- [       Thread-2] c.l.m.w.e.nodes.InputParamExtractor      : Request Payload : {\ currentTime\ :\ 2024-05-28 09:35:35\ ,\ instanceId\ :\ 00000\ ,\ objectName\ :\ MASTER_DATA_WF_1\ ,\ lastRunDate\ :\ \ ,\ lastSuccessfulRunDate\ :\ \ ,\ userId\ :\ fdcuser@fosfor.com\ } },{ logId : 89912 , log : 2024-05-28T09:37:32.275Z  INFO 58 --- [       Thread-2] c.l.m.w.e.nodes.InputParamExtractor      : received Response : {\ currentTime\ :\ 2024-05-28 09:35:35\ ,\ instanceId\ :\ 00000\ ,\ objectName\ :\ MASTER_DATA_WF_1\ ,\ lastRunDate\ :\ \ ,\ lastSuccessfulRunDate\ :\ \ ,\ userId\ :\ fdcuser@fosfor.com\ } },{ logId : 90236 , log : 2024-05-28T09:37:32.276Z ERROR 58 --- [       Thread-2] c.l.m.w.e.nodes.InputParamExtractor      : Error while refreshing input parameters : {} },{ logId : 90420 , log :  },{ logId : 90461 , log : com.fasterxml.jackson.databind.exc.MismatchedInputException: Cannot deserialize value of type `java.util.ArrayList<java.lang.Object>` from Object value (token `JsonToken.START_OBJECT`) },{ logId : 90686 , log :  at [Source: (String)\ {\ currentTime\ :\ 2024-05-28 09:35:35\ ,\ instanceId\ :\ 00000\ ,\ objectName\ :\ MASTER_DATA_WF_1\ ,\ lastRunDate\ :\ \ ,\ lastSuccessfulRunDate\ :\ \ ,\ userId\ :\ fdcuser@fosfor.com\ }\ ; line: 1, column: 1]"
""""text_url = 'C:/fosfor-ai-code/refract-common-service/sampleLogs/cluster.log'

text_splitter = CharacterTextSplitter(
    separator= ",{",
    chunk_size = 200
)

loader = TextLoader(text_url)
log_text = loader.load_and_split(
    text_splitter=text_splitter
)

for doc in log_text:
    print(doc.page_content)
    print("\n\n")

#embeddings = SentenceTransformerEmbeddings(model_name ="paraphrase-albert-small-v2") ##("all-MiniLM-L6-v2") 
#SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

embeddings = model.encode(log_text)
db = Chroma.from_documents(log_text, embeddings, persist_directory="emb1")

query = "what is the latest error message"
docs = db.similarity_search_with_score(query)

for result in docs:
    print("\n")
    print(result[1])
    print(docs[0].page_content)

"""
prompt_template1 = """
## Role : Act as a Python developer expert in debugging error logs. 
##Task : You need to generate a conscise summary and recommendations in seperate sections for the user log
##Rules: You need to follow following rules
  1. The summary should be in the order of the logs
  2. The summary should be in simple english and should not contain any technical jargons
  3. The summary should not contain any redundant information

This is the user log
{text}

SUMMARY:"""


prompt = PromptTemplate(template=prompt_template1, input_variables=["log_text"])

gpt_35_turbo_max_tokens = 100
verbose = True

#chain = load_summarize_chain(llm, chain_type="stuff", prompt=prompt, verbose=verbose)
##summary = chain.run(docs)
#summary = chain.invoke(log_text)

##print(f"Chain type: {chain.__class__.__name__}")
#print(f"Summary: {summary['output_text']}")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# /tmp/pip_packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ...
